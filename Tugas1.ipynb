# %%
import tweepy
import datetime
from tweepy import OAuthHandler, Stream, StreamListener

consumer_key="avLu8KO8eVTBeiTttRXHsvU6r"
consumer_secret="dVTKCvMKfmvdk9Lu1Yv4Cn54AdGvompSAwBme0aFC2fLqPalJ9"
access_token="1098368194765414400-yMsWFbeVQ8Yzu7YO4vq0BjJoVzeSXs"
access_token_secret="lMjzDDL76xpfTL4EhTAc5uOQogiDpZb6uAk6hhmXAmKdn"
auth = OAuthHandler(consumer_key, consumer_secret,)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
#Mengambil tweet dari username lain (Swarrsss) 
#Print dengan format json
user_tweets = api.user_timeline(screen_name='Swarrsss', count=50, tweet_mode="extended",  )
for tweet in user_tweets:
    print(tweet._json)
# Out:
# {'created_at': 'Sat Oct 26 12:50:31 +0000 2019', 'id': 1188075432618258434, 'id_str': '1188075432618258434', 'full_text': 'Terpisahkan jarak (?)', 'truncated': False, 'display_text_range': [0, 21], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 308820901, 'id_str': '308820901', 'name': 'Aswar', 'screen_name': 'Swarrsss', 'location': '', 'description': 'Statistics Undergraduate', 'url': 'https://t.co/7eMmQksi0t', 'entities': {'url': {'urls': [{'url': 'https://t.co/7eMmQksi0t', 'expanded_url': 'http://Instagram.com/swarrss', 'display_url': 'Instagram.com/swarrss', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 893, 'friends_count': 144, 'listed
# ...

# %%
#membuat variable list
the_list = []
tweet_aswar = api.user_timeline(screen_name='Swarrsss', count=50, tweet_mode="extended")
startDate = datetime.datetime(2019, 10, 22, 0, 0, 0)
endDate =   datetime.datetime(2019, 10, 24, 0, 0, 0)

#menambahkan objek tweet._json kedalam variable the_list
for tweet in tweet_aswar:
    if tweet.created_at < endDate and tweet.created_at > startDate:
        the_list.append(tweet._json)

# %%
import pandas 
myData = pandas.DataFrame(the_list)
myData
# Out:
#                         created_at                   id               id_str  \
# 0   Wed Oct 23 12:52:01 +0000 2019  1186988647721005056  1186988647721005056
# 1   Wed Oct 23 12:49:01 +0000 2019  1186987891987058688  1186987891987058688
# 2   Wed Oct 23 10:28:19 +0000 2019  1186952483718852614  1186952483718852614
# 3   Wed Oct 23 03:06:17 +0000 2019  1186841243973607425  1186841243973607425
# 4   Wed Oct 23 02:39:31 +0000 2019  1186834507107749888  1186834507107749888
# 5   Wed Oct 23 00:44:48 +0000 2019  1186805639281926144  1186805639281926144
# 6   Tue Oct 22 14:39:17 +0000 2019  1186653253309620226  1186653253309620226
# 7   Tue Oct 22 14:05:41 +0000 2019  1186644797777420289  1186644797777420289
# 8   Tue Oct 22 14:05:19 +0000 2019  1186644705062375425  1186644705062375425
# 9   Tue Oct 22 13:25:23 +0000 2019  1186634656000528384  1186634656000528384
# 10  Tue Oct 22 09:09:32 +0000 2019  1186570268468117504  1186570268468117504
# ...
